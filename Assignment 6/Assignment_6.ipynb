# %%
import numpy as np
from scipy.stats import norm, expon, chi2, uniform
import matplotlib.pyplot as plt
# %matplotlib inline


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Standard distributions sampling
# ## Ex 1.
# Use scipy to take samples from the following distributions:
# 1. Normal distribution with $\mu$=1 and $\sigma$=4,
# 2. Exponential distribution with $\lambda = \dfrac{1}{4}$,
# 3. Chi-squared distribution with 8 degrees of freedom,
# 4. Uniform distribution with borders [$-2\sqrt{3}, 6\sqrt{3}$].
#
# Compare their theoretical and sample distribution, mean and variance.

# %%
#1. Normal
#This one I'll do for you :-)

rv_norm = norm(loc = 1, scale = 4)
x = np.linspace(rv_norm.ppf(0.01), rv_norm.ppf(0.99), 100)
fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_norm.pdf(x), 'r-', lw=5, alpha=0.6, label='norm pdf')
r = rv_norm.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])


ax.legend(loc='best', frameon=False)
plt.show()

print("Distribution mean: {0}".format(rv_norm.stats(moments='m')))
print("Distribution variance: {0}".format(rv_norm.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))
# Out:
# Distribution mean: 1.0
# Distribution variance: 16.0
# Sample mean: 1.0833586427547603
# Sample variance: 15.963090088469999

# %%
#Exponential
#here goes your code
exponential = expon(scale = 4)
x = np.linspace(exponential.ppf(0.01), exponential.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, exponential.pdf(x), 'r-', lw=5, alpha=0.6, label='exponential pdf')
r = exponential.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()
print("Distribution mean: {0}".format(exponential.stats(moments='m')))
print("Distribution variance: {0}".format(exponential.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))
#hint: expon
# Out:
# Distribution mean: 4.0
# Distribution variance: 16.0
# Sample mean: 3.840977486518067
# Sample variance: 13.085058442924995

# %%
#chi2
#here goes your code

rv_chi2 = chi2(df=8)
x = np.linspace(rv_chi2.ppf(0.01), rv_chi2.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_chi2.pdf(x), 'r-', lw=5, alpha=0.6, label='chi2 pdf')
r = rv_chi2.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()
print("Distribution mean: {0}".format(rv_chi2.stats(moments='m')))
print("Distribution variance: {0}".format(rv_chi2.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))
#hint: chi2

#chi2
#here goes your code
# Out:
# Distribution mean: 8.0
# Distribution variance: 16.0
# Sample mean: 7.762137254129202
# Sample variance: 15.800317922734088

# %%
#uniform
import math
#here goes your code
rv_uniform = uniform(-2 * math.sqrt(3),6 * math.sqrt(3))
x = np.linspace(rv_uniform.ppf(0.01), rv_uniform.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, rv_uniform.pdf(x), 'r-', lw=5, alpha=0.6, label='uniform pdf')
r = rv_uniform.rvs(size=1000)
ax.hist(r, density=True, histtype='stepfilled', alpha=0.2, bins = x[::4])
ax.legend(loc='best', frameon=False)
plt.show()
print("Distribution mean: {0}".format(rv_uniform.stats(moments='m')))
print("Distribution variance: {0}".format(rv_uniform.stats(moments='v')))
print("Sample mean: {0}".format(np.mean(r)))
print("Sample variance: {0}".format(np.var(r)))

#hint: uniform
# Out:
# Distribution mean: 1.7320508075688776
# Distribution variance: 9.0
# Sample mean: 1.6252162316799286
# Sample variance: 8.936052645615916

# %% [markdown]
# ## Summary:
# As we can see the distribution mean and sample mean values were almost identical. Same goes for distribution variance and sample variance.

# %% [markdown]
# # Low of large numbers. Central Limit Theorem.
# ## Ex 2.
# a) For N from 2 to 1000 draw N samples from distributions defined in Ex 1. Plot sample variance and mean against the size of the sample.

# %%
#here goes your code

mylist = []
for i in range (2,1000):
  rv_norm = norm(loc = 1, scale = 4)
  r = rv_norm.rvs(size=i)
  mylist.append(np.mean(r))
  mylist.append(np.var(r))
  mylist.append(i)
plt.plot(mylist[2::3],mylist[1::3] , 'r-', lw=1, alpha=0.6, label='norm var', color="blue")
plt.legend(loc='best', frameon=False)
plt.show()
plt.plot(mylist[2::3],mylist[0::3] , 'r-', lw=1, alpha=0.6, label='norm mean')
plt.legend(loc='best', frameon=False)
plt.show()

mylist = []
for i in range (2,1000):
  rv_norm = expon(scale = 4)
  r = rv_norm.rvs(size=i)
  mylist.append(np.mean(r))
  mylist.append(np.var(r))
  mylist.append(i)
plt.plot(mylist[2::3],mylist[1::3] , 'r-', lw=1, alpha=0.6, label='expon var',color="blue")
plt.legend(loc='best', frameon=False)
plt.show()
plt.plot(mylist[2::3],mylist[0::3] , 'r-', lw=1, alpha=0.6, label='expon mean')
plt.legend(loc='best', frameon=False)
plt.show()

mylist = []
for i in range (2,1000):
  rv_norm = chi2(df=8)
  r = rv_norm.rvs(size=i)
  mylist.append(np.mean(r))
  mylist.append(np.var(r))
  mylist.append(i)
plt.plot(mylist[2::3],mylist[1::3] , 'r-', lw=1, alpha=0.6, label='chi2 var',color="blue")
plt.legend(loc='best', frameon=False)
plt.show()
plt.plot(mylist[2::3],mylist[0::3] , 'r-', lw=1, alpha=0.6, label='chi2 mean')
plt.legend(loc='best', frameon=False)
plt.show()

mylist = []
for i in range (2,1000):
  rv_norm = uniform(-2 * math.sqrt(3),6 * math.sqrt(3))
  r = rv_norm.rvs(size=i)
  mylist.append(np.mean(r))
  mylist.append(np.var(r))
  mylist.append(i)
plt.plot(mylist[2::3],mylist[1::3] , 'r-', lw=1, alpha=0.6, label='uniform var',color="blue")
plt.legend(loc='best', frameon=False)
plt.show()
plt.plot(mylist[2::3],mylist[0::3] , 'r-', lw=1, alpha=0.6, label='uniform mean')
plt.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Summary:
# We can observe that with increase of sample size - sample variances are getting closer to the theoretical values.

# %% [markdown]
# ## Ex 3.
# For N=1,4,9,16 draw histograms of an average over N samples taken from distributions defined in Ex 1.

# %%
#here goes your code
mylist = []
kolor = ["red","green","blue","yellow"]
fig, ax = plt.subplots(1, 1)
for j in range(1,5):
  for i in range (2,1000):
    rv_norm = norm(loc = 1, scale = 4)
    r = rv_norm.rvs(size=(j*j))
    mylist.append(np.mean(r))
    # print(np.mean(r))
    # print(np.var(r))
    # print(" ")
  # mylist[2::3]
  ax.hist(mylist, bins = 20,alpha=0.3,density=True,label = str(j*j) + " normal")
plt.legend(loc='best', frameon=False)
plt.show()
#here goes your code
mylist = []
kolor = ["red","green","blue","yellow"]
fig, ax = plt.subplots(1, 1)
for j in range(1,5):
  for i in range (2,1000):
    rv_norm = expon(scale = 4)
    r = rv_norm.rvs(size=(j*j))
    mylist.append(np.mean(r))
    # print(np.mean(r))
    # print(np.var(r))
    # print(" ")
  # mylist[2::3]
  ax.hist(mylist, bins = 20,alpha=0.3,density=True,label = str(j*j) + " expon")
plt.legend(loc='best', frameon=False)
plt.show()

#here goes your code
mylist = []
kolor = ["red","green","blue","yellow"]
fig, ax = plt.subplots(1, 1)
for j in range(1,5):
  for i in range (2,1000):
    rv_norm = chi2(df=8)
    r = rv_norm.rvs(size=(j*j))
    mylist.append(np.mean(r))
    # print(np.mean(r))
    # print(np.var(r))
    # print(" ")
  # mylist[2::3]
  ax.hist(mylist, bins = 20,alpha=0.3,density=True,label = str(j*j) + " chi2")
plt.legend(loc='best', frameon=False)
plt.show()

#here goes your code
mylist = []
kolor = ["red","green","blue","yellow"]
fig, ax = plt.subplots(1, 1)
for j in range(1,5):
  for i in range (2,1000):
    rv_norm = uniform(-2 * math.sqrt(3),6 * math.sqrt(3))
    r = rv_norm.rvs(size=(j*j))
    mylist.append(np.mean(r))
    # print(np.mean(r))
    # print(np.var(r))
    # print(" ")
  # mylist[2::3]
  ax.hist(mylist, bins = 20,alpha=0.3,density=True,label = str(j*j) + " uniform")
plt.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Summary:
# With the increase of sample size our histogram is mostly distributed around true mean value of the distribution. \
# X axis is average number of samples. \
# Y axis is density.

# %% [markdown]
# # Arbitrary distribution sampling
#
# Sometimes it may happen, that we need to sample from a custom distribution, not implemented in any standard library. There exist a simple algorithm for such sampling, provided that the distribution is bounded (pdf has finite support and maximum).
#
#
# #### Accept-rejection sampling
# Let the distribution be given by the pdf $g(x)$ and defined at interval $[a,b]$. In addition, let $M$ be the supremum of $g(x)$.
#
# 1. Take a sample $t$ from the uniform distribution at the interval $[a,b]$,
# 2. Take a sample $u$ from the uniform distribution at the interval $[0,M]$,
# 3. If $g(t) > u$ we accept $t$ as a sample taken from the original distribution. If not, we go back to 1.
#
# ## Ex 4.
# Implement function accept_rejection_sampling(dist, size = 1) which samples from any bounded distribution on the [0,1] interval.

# %%
def toy_dist(x):
    C = 1/3 - np.exp(-4)/4 + 1/4
    return (x**2 + np.exp(-4*x)) / C 

x = np.linspace(0,1,1000)

def accept_rejection_sampling(dist, size = 1):
    #here goes your code
    samplesArray = []
    M = max(dist)
    
    while(len(samplesArray)<size):
        u = uniform.rvs(0,M)
        t = uniform.rvs(0,1)
        
        if(toy_dist(t)>u):
            samplesArray.append(t)
    return samplesArray


samples = accept_rejection_sampling(toy_dist(x), size = 10000)

fig, ax = plt.subplots(1, 1)
ax.plot(x, toy_dist(x), 'r-', lw=5, alpha=0.6, label='toy pdf')
ax.hist(samples, density=True, histtype='stepfilled', alpha=0.2, bins = x[::40], label = "sampled")
ax.legend(loc='best', frameon=False)
plt.show()

# %% [markdown]
# # Probability space matters!
# ## Ex 5
# Sample 2000 points from the unit disk. Do it in following ways:
# 1. Assume uniform distribution of radius (0,1) and argument (0,2$\pi$),
# 2. Assume uniform distribution of x and y coordinate (-1,1). Drop values laying outside of the disk.
# Explain differences. between 1. and 2. Then:
# 3. Modify the solution of point 1. by changing the distribution of the radius in such a way, that we result in 2D distribution from 2.

# %%
#Version1
#here goes your code
rv_uniform_x = uniform(loc = -1, scale = 2)
rv_uniform_y = uniform(loc = -1, scale = 2)
x = rv_uniform_x.rvs(size=2000)
y = rv_uniform_y.rvs(size=2000)
data = [x,y]
deletearray = []
for i in range (np.size(data[0])):
    if ((data[0][i]*data[0][i]) +(data[1][i] * data[1][i] )> 1):
      deletearray.append(i)
data[0] = np.delete(data[0], deletearray)
data[1] = np.delete(data[1], deletearray)
print(data)
data[1][2]
plt.scatter(data[0],data[1], label='x and y',s=3)
plt.show()
plt.hist(data[0],alpha=0.3,density=True,label = str(j*j) + "x")
plt.show()
plt.hist(data[1],alpha=0.3,density=True,label = str(j*j) + "y")
plt.show()
# Out:
# [array([-0.0502696 , -0.11837717,  0.6847724 , ...,  0.05151384,
#         0.81791147,  0.74060658]), array([-0.23434035,  0.67765582, -0.33235594, ...,  0.03445535,
#         0.03121145,  0.44514193])]

# %%
#Version2
#here goes your code
data = [[],[]]
rv_uniform_rad = uniform(loc = 0, scale = 1)
rv_uniform_arg = uniform(loc = 0, scale = 2 * math.pi)
rad = rv_uniform_rad.rvs(size=2000)
arg = rv_uniform_arg.rvs(size=2000)
print(rad)
print(arg)
for i in range (np.size(rad)):
    data[0].append(math.cos(arg[i])*rad[i])
    data[1].append(math.sin(arg[i])*rad[i])
plt.scatter(data[0],data[1], alpha = 0.5,label='chi2 pdf',s=3)
plt.show()

plt.hist(rad,alpha=0.3,density=True,label = str(j*j) + "radius")
plt.show()
plt.hist(arg,alpha=0.3,density=True,label = str(j*j) + " argument")
plt.show()
# Out:
# [0.75486481 0.39938927 0.10391662 ... 0.44483653 0.11216067 0.08858695]
# [5.17199658 5.59383442 5.72564897 ... 4.45383709 3.98731522 2.63516207]

# %%
#Version3
#here goes your code
data = [[],[]]
rv_uniform_rad = uniform(loc = 0, scale = 1)
rv_uniform_arg = uniform(loc = 0, scale = 2 * math.pi)
rad = rv_uniform_rad.rvs(size=2000)
arg = rv_uniform_arg.rvs(size=2000)

for i in range (np.size(rad)):
    rad[i] = math.sqrt(1-rad[i])
    data[0].append(math.cos(arg[i])*rad[i])
    data[1].append(math.sin(arg[i])*rad[i])

plt.figure().set_figwidth(10)
plt.figure().set_figheight(10)
plt.scatter(data[0],data[1], alpha = 0.5,label='chi2 pdf',s=1)
plt.show()

plt.hist(rad,alpha=0.3,density=True,label = str(j*j) + "radius")
plt.show()
plt.hist(arg,alpha=0.3,density=True,label = str(j*j) + " argument")
plt.show()

# %% [markdown]
# ## Summary:
# Area of the circle corresponding to radius < 0.5 equals 0.25 pi. \
# Area of the circle corresponding to radius > 0.5 equals 0.75 pi. \
# This shows that when it comes to choosing a random point on a circle it would be a mistake to use normal distribution for choosing radius. \
# To fix that I have used square root of (1 - radius).

# %% [markdown]
# ## Application: Laplace equation, Dirichlet boundary conditions
#
# #### Monte-Carlo procedure for solving 2D Laplace equation with Dirichlet boundary conditions
# 1. Start in a random position inside the boundaries,
# 2. With an equal probability move up/down/right/left until you hit the boundary,
# 3. After hitting the boundary we take the value $v_{b}$ of the function in the hitting point. We update the values of all points along the just finished random walk using the formula:
# $$ v_{new} = \dfrac{nv_{old} + v_{b}}{n+1}, $$
# where $n$ is a number of random walks which have already passed through this point.
# 4. Finish if the desired precision is achieved. If not, go back to 1.
#
#
# A theory behind the above procedure can be found here:
# https://www.uzh.ch/cmsssl/physik/dam/jcr:d559688c-1e7f-44ca-9fbe-aab0755c0b6e/empp18_MC_Markov.pdf

# %% [markdown]
# ## Ex 6
# Implement the method described above and solve numerically given Dirichlet problem. Plot few intermediate steps.

# %%
S = 50 # Decrease if computations take too long
plane = np.zeros((S,S))
plane_counts = np.zeros((S,S))
plane[0] = np.cos(np.linspace(-1.5,1.5,S)*2*np.pi)
plane[-1] = -np.cos(np.linspace(-1,1,S)*2*np.pi)
plane[:,0] = np.cos(np.linspace(-0.5,0.5,S)*2*np.pi)
plane[:,-1] = -2+np.linspace(-1,1,S)**2

# %%
plt.figure(figsize=(10,15))
plt.title("0 walks")
plt.imshow(plane)

# %%
#here goes your code

import random
np.random.seed(0)

x = np.random.randint(1, S-1)
y = np.random.randint(1, S-1)
pow = 8
plots = []
for i in range (1000):
  moves = []
  while x!=0 and x!=S-1 and y!=0 and y!=S-1:
    plane_counts[x][y] += 1
    roll = np.random.randint(1, 5)
    if roll==1:
      x+=1
    if roll==2:
      x-=1
    if roll==3:
      y+=1
    if roll==4:
      y-=1
    moves.append([x,y])
  moves.pop()
  while np.size(moves) != 0:
    xmove,ymove = moves.pop()
    plane[xmove][ymove]=((plane[xmove][ymove]*plane_counts[xmove][ymove])+plane[x][y])/(plane_counts[xmove][ymove]+1)
  x = np.random.randint(1, S-2)
  y = np.random.randint(1, S-2)
  if i == pow:
    plt.figure(figsize=(5,10))
    plots.append(plt.imshow(plane))
    pow *= 2
plt.figure(figsize=(5,10))
plots.append(plt.imshow(plane))
plt.draw()

# %% [markdown]
# # Summary
# Plots above shows how the plane changes with increase of number of walks.
# I've decided to show how the plane changes when we double the number of walks, starting from 8.
